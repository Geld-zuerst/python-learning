# %%
# 1. Missing colon after if
if x > 5
    print("Greater")

# %%
# 2. Unmatched parenthesis
print("Hello"

# %%
# 3. Wrong indentation
def greet():
print("Hi")

# %%
# 4. Using = instead of == in condition
if x = 10:
    print("Ten")

# %%
# 5. Missing closing quote
msg = "Hello
print(msg)

# %%
# 6. Invalid variable name (starts with number)
2count = 5
print(2count)

# %%
# 7. Missing comma in function arguments
print("Hello" "World")

# %%
# 8. Incomplete list syntax
numbers = [1, 2, 3
print(numbers)

# %%
# 9. Missing colon after for loop
for i in range(5)
    print(i)

# %%
# 10. Missing colon after while loop
while True
    print("Infinite")

# %%
# 11. Missing colon after function definition
def add(a, b)
    return a + b

# %%
# 12. Using Python keyword as variable name
if = 10
print(if)

# %%
# 13. Unmatched curly brace
data = {1: "one", 2: "two"
print(data)

# %%
# 14. Mixing tabs and spaces (IndentationError)
def test():
    print("Tab")
	print("Space")  # yahan tab + space mix hai

# %%
# 15. Missing comma in list
items = [1 2, 3]
print(items)
