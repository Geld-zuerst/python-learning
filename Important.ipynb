# %% [markdown]
# ### UNI CODE

# %%
print("A">"a")

# unicode ke hisab se "a" bada hota hai
# Out:
# False

# %%
print(ord("a"))
print(ord("A"))
# Out:
# 97
# 65

# %%
print(chr(65))
# Out:
# A

# %%
print(("cat">"car"))
# Out:
# True

# %%
print((ord("r")))
print(ord("t"))
# Out:
# 114
# 116

# %%
s1 = 'Hello'

s2 = "Hello"

s3 = '''Hello'''

s4 = """Hello"""

s5 = str(123)

name = "Alice"
s6 = f"Hello, {name}"



print(type(s1))
print(type(s2))
print(type(s3))
print(type(s4))
print(type(s5))
print(type(s6))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
s7 = "Hello \nI'm Harsh Tiwari from Bihar \nCurrently doing python."
print(s7)
# Out:
# Hello
# I'm Harsh Tiwari from Bihar
# Currently doing python.

# %%
print("python".title())
# Out:
# Python

# %%
print("PyThOn".swapcase())
# Out:
# pYtHoN

# %%
print("PyThOn".casefold())
# Out:
# python

# %%
print("Python".center(50))
# Out:
#                       Python

# %%
print("Python".ljust(60))
# Out:
# Python

# %%
print("Python".rjust(60))
# Out:
#                                                       Python

# %%
print("43".zfill(5))
# Out:
# 00043

# %%
s8 = "Python"
print(s8.index("y"))
# Out:
# 1

# %%
s9 = "Banana"
print(s9.count("a"))
print(s9.startswith("B"))
print(s9.endswith("a"))
# Out:
# 3
# True
# True

# %%
print("Quad".isalpha())
# Out:
# True

# %%
print("Quad123".isalnum())
# Out:
# True

# %%
print("123".isnumeric())
# Out:
# True

# %%
print("123".isdigit())
# Out:
# True

# %%
print("12".isdecimal())
# Out:
# True

# %%
print("".isspace())
print(" ".isspace())
# Out:
# False
# True

# %%
"""
hello 
how are u doing
helooooooooooooooooo
hiiiiiiiiiii
heloooooooooo
"""
print("Hello")
# Out:
# Hello

# %%
print(s8[::-1])
# Out:
# nohtyP
