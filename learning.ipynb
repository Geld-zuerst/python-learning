# %%
age = 20
print(age)
print(type(age))
# Out:
# 20
# <class 'int'>

# %%
price= 3.15
print(price)
print(type(price))
# Out:
# 3.15
# <class 'float'>

# %%
name ="Harsh"
print(name)
print(type(name))
# Out:
# Harsh
# <class 'str'>

# %%
is_student = True
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
marks = [1,2,5]
print(marks)
print(type(marks))
# Out:
# [1, 2, 5]
# <class 'list'>

# %%
coordinates = (10,20)
print(coordinates)
print(type(coordinates))
# Out:
# (10, 20)
# <class 'tuple'>

# %%
numbers = {10,20,20,30}
print(numbers)
print(type(numbers))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
student = {
    "name": "Harsh",
    "age":18
}
print(student)
print(type(student))
# Out:
# {'name': 'Harsh', 'age': 18}
# <class 'dict'>

# %%
z = 2 + 3j
print(type(z))
print(z.real)
print(z.imag)
# Out:
# <class 'complex'>
# 2.0
# 3.0
