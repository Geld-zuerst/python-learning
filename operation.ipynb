# %%
array = ["Harsh", "Samar", "Siddarth", ]
num = [1, 2, 3, 4, 5, 6, 7, 8, 9]

print(array)
print(type(array))
# Out:
# ['Harsh', 'Samar', 'Siddarth']
# <class 'list'>

# %%
b = list(("a","b","c"))
print(b)
# Out:
# ['a', 'b', 'c']

# %%
print(array[0])
print(array[1])

print(array[-2])
print(array[-1])
# Out:
# Harsh
# Samar
# Samar
# Siddarth

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]

smt = nums[:4]
print(smt)
# Out:
# [10, 20, 30, 40]

# %%
smt2 = nums[1:4]
print(smt2)
# Out:
# [20, 30, 40]

# %%
print(nums[4:7])
# Out:
# [50, 60, 70]

# %%
smt3 = nums[1:10:2]
print(smt3)
# Out:
# [20, 40, 60, 80]

# %%
smt4 = nums[5:]
print(smt4)
# Out:
# [60, 70, 80, 90]

# %%
marks = [80, 85, 90, 95]
print(marks)
# Out:
# [80, 85, 90, 95]

# %%
marks.append(100)
print(marks)
# Out:
# [80, 85, 90, 95, 100]

# %%
marks.append(98)
print(marks)
# Out:
# [80, 85, 90, 95, 100, 98]

# %%
marks.extend([99,87,89])
print(marks)
# Out:
# [80, 85, 90, 95, 100, 98, 99, 87, 89]

# %%
lang = ["Java", "Python", "JavaScript", "HTML"]
lang.insert(0, "Machine Learning")

print(lang)
# Out:
# ['Machine Learning', 'Java', 'Python', 'JavaScript', 'HTML']

# %%
# clear()
a = [1, 2, 3]
a.clear()
print(a)

# %%
# count()
a = [10, 20, 20, 30, 20]
print(a.count(20))

# %%
a = [40, 10, 30, 20]
a.sort()
print(a)
# Out:
# [10, 20, 30, 40]

# %%
# 
a.sort(reverse=True)
print(a)

# %%
# Reverse()
a = [1, 2, 3, 4]
a.reverse()
print(a)

# %%
# copy()
a = [1, 2, 3]
b = a.copy()
print(b)

# %%
# Concatenation
a = [1, 2]
b = [3, 4]
print(a + b)

# %%
# Repetition
a = [1, 2]
print(a * 3)

# %%
# Membership: in
a = [10, 20, 30]
print(20 in a) 
print(50 in a)

# %%
# Membership: not in
print(50 not in a)

# %%
# Comparison
print([1, 2] == [1, 2])  
print([1, 2] != [1, 3])

# %%
a = [10, 20, 30, 40]

print(len(a))
print(min(a))
print(max(a))
print(sum(a))

# %%
# Other Useful Functions
print(sorted(a))
print(list(reversed(a)))
print(any(a))
print(all(a))
